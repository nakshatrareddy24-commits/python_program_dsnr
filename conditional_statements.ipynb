# %%
# conditional statements in python
1. python have 3 types of conditional statements
2. if statement
3. elif statement
4. else statement

```python
if (logic):
    statements
```

```python if,else
if (logic):
    statements
else:
    statements
```

```python if,elif,else
if (logic):
    statements
elif (logic):
    statements
elif (logic):
    statements
elif ...
else:
    statements
```

# %%
# write a program to check given number is even
num=int(input("please enter a number:"))
if (num%2 == 0):
    print(num,"is even number")
# Out:
# please enter a number: 24
# 24 is even number

# %%
#write a program to find the given number is odd or even number
num=int(input("please enter a number:"))
if (num%2 == 0):
    print(num,"is even number")
else:
    print(num,"is odd number")
# Out:
# please enter a number: 19
# 19 is odd number

# %%
n = int(input("please enter a number:"))
if (n%2 == 1):
    print(n,"is odd number")
else:
    print(n,"is even number")
# Out:
# please enter a number: 14
# 14 is even number

# %%
#write a program to find the given number is positive or negative or zero
n = int(input("please enter a number:"))
if (n>0):
    print(n,"is positive number")
elif (n<0):
    print(n,"is negative number")
else:
    print(n,"is zero")
# Out:
# please enter a number: -25
# -25 is negative number

# %%
"""
write a program to find out the grade based on students marks
1. if marks is b/w 80 to 100 grade A
2. if marks is b/w 60 to 79 grade B
3. if marks is b/w 40 to 59 grade c
4. if marks is b/w 25 to 39 grade D
5. if marks is b/w 0 to 24 grade fail
6. if marks other than above output should be please check valid marks
"""
marks = int(input("please enter student marks here:"))
if (marks>=80 and marks<=100):
    print(marks,"A grade")
elif (marks>=60 and marks<=79):
    print(marks,"B grade")
elif (marks>=40 and marks<=59):
    print(marks,"C grade")
elif (marks>=25 and marks<=39):
    print(marks,"D grade")
elif (marks>=0 and marks<=24):
    print(marks,"FAIL grade")
else:
    print(marks,"invalid")
# Out:
# please enter student marks here: 1
# 1 FAIL grade

# %%
#1. write a program to find the largest number from three numbers
#2. write a calculator program using conditional statements
#3. write a program to  validate login credentials using conditional statements

# %%
n1=int(input("please enter 1st number here:"))
n2=int(input("please enter 2nd number here:"))
n3=int(input("please enter 3rd number here:"))
if (n1>=n2 and n1>=n3):
    print(n1,"is largest number")
elif(n2>=n1 and n2>=n3):
    print(n2,"is largest number")
else:
    print(n3,"is largest number")
# Out:
# please enter 1st number here: 8
# please enter 2nd number here: 8
# please enter 3rd number here: 8
# 8 is largest number

# %%
print("welcome to calculator application")
v1=int(input("enter first number here:"))
v2=int(input("enter second number here:"))
options=int(input("please select below options \n1.addition \n2.subtraction \n3.multiplication \n4.division \n"))
if (options==1):
    print("addition of two number is:",v1+v2)
elif(options==2):
    print("subtraction of two numbers is:",v1-v2)
elif(options==3):
    print("multiplication of two numbers is:",v1*v2)
elif(options==4):  
    print("division of two numbers is:",v1/v2)
else:
    print("choose correct options")
# Out:
# welcome to calculator application
# enter first number here: 2
# enter second number here: 2
# please select below options
# 1.addition
# 2.subtraction
# 3.multiplication
# 4.division
#  2
# subtraction of two numbers is: 0

# %%
username=str(input("please enter username here:"))
if (username=="nakshatra2421"):
    print("user name is valid")
    pwd=str(input("please enter your password here:"))
    if(pwd=="a@2421"):
        print("your password is valid")
        print(username,"welcome to python workshop")
    else:
        print("password is invalid,please check again")
else:
    print("username is invalid,please recheck")
